# %% [markdown]
# <html>
# <table width="100%" cellspacing="2" cellpadding="2" border="1">
# <tbody>
# <tr>
# <td valign="center" align="center" width="25%"><img src="../../media/decartes.jpg"
# alt="DeCART Icon" width="128" height="171"><br>
# </td>
# <td valign="center" align="center" width="75%">
# <h1 align="center"><font size="+3">DeCART Summer School<br>
# for<br>
# Biomedical Data Science</font></h1></td>
# <td valign="center" align="center" width="25%"><img
# src="../../media/U_Health_stacked_png_red.png" alt="Utah Health
# Logo" width="128" height="134"><br>
# </td>
# </tr>
# </tbody>
# </table>
# <br>
# </html>
#
#
# # Working with Textual Data
# #### &copy; Brian E. Chapman, Ph.D.
#
#
# ### To get the latest version of this lesson, execute the cell below

# %%
rad_data[rad_data["IMPRESSION"] !=","]
# Out:
#       subject_id  hadm_id                                               text  \
# 0             56    28766  \n\n\n     DATE: [**2644-1-17**] 10:53 AM\n   ...
# 1             56    28766  \n\n\n     DATE: [**2644-1-17**] 10:53 AM\n   ...
# 2             56    28766  \n\n\n     DATE: [**2644-1-17**] 10:43 AM\n   ...
# 3             56    28766  \n\n\n     DATE: [**2644-1-17**] 6:37 AM\n    ...
# 4             56    28766  \n\n\n     DATE: [**2644-1-19**] 12:09 PM\n   ...
# 5             37    18052  \n\n\n     DATE: [**3264-8-14**] 6:06 AM\n    ...
# 6             37    18052  \n\n\n     DATE: [**3264-8-14**] 10:57 AM\n   ...
# 7             37    18052  \n\n\n     DATE: [**3264-8-15**] 9:26 AM\n    ...
# 8             37    18052  \n\n\n     DATE: [**3264-8-15**] 3:49 PM\n    ...
# 9             37    18052  \n\n\n     DATE: [**3264-8-15**] 3:49 PM\n    ...
# 10            37    18052  \n\n\n     DATE: [**3264-8-16**] 1:53 PM\n    ...
# 11            37    18052  \n\n\n     DATE: [**3264-8-16**] 3:45 PM\n    ...
# 12            37    18052  \n\n\n     DATE: [**3264-8-17**] 9:46 AM\n    ...
# 13            37    18052  \n\n\n     PERSANTINE MIBI                    ...
# 14            78      NaN  \n\n\n     DATE: [**2778-3-22**] 7:58 PM\n    ...
# 15            78    15161                                             \n\n\n
# 16            78    15161  \n\n\n     DATE: [**2778-3-24**] 12:55 PM\n   ...
# 17            26    15067  \n\n\n     DATE: [**3079-3-6**] 8:03 AM\n     ...
# 18            26    15067  \n\n\n     DATE: [**3079-3-7**] 11:35 AM\n    ...
# 19            61     7149  \n\n\n     DATE: [**3352-6-23**] 7:18 PM\n    ...
# 20            61     7149  \n\n\n     DATE: [**3352-7-6**] 10:20 AM\n    ...
# 21            61     7149  \n\n\n     DATE: [**3352-7-8**] 10:29 AM\n    ...
# 22            61     7149  \n\n\n     DATE: [**3352-7-10**] 1:35 PM\n    ...
# 23            61     7149  \n\n\n     DATE: [**3352-7-12**] 9:08 PM\n    ...
# 24            61     7149  \n\n\n     DATE: [**3352-7-16**] 5:21 PM\n    ...
# 25            61     7149  \n\n\n     DATE: [**3352-7-16**] 5:21 PM\n    ...
# 26            61     7149  \n\n\n     DATE: [**3352-7-16**] 5:21 PM\n    ...
# 27            61     7149  \n\n\n     DATE: [**3352-7-16**] 5:21 PM\n    ...
# 28            61     7149  \n\n\n     DATE: [**3352-7-18**] 8:52 AM\n    ...
# 29            61     7149  \n\n\n     DATE: [**3352-7-19**] 9:38 AM\n    ...
# ...          ...      ...                                                ...
# 9970        3841     2472  \n\n\n     DATE: [**3031-4-5**] 6:32 AM\n     ...
# 9971        3841     2472                                             \n\n\n
# 9972        3841     2472  \n\n\n     DATE: [**3031-4-6**] 6:16 PM\n     ...
# 9973        3841     2472  \n\n\n     DATE: [**3031-4-6**] 1:56 PM\n     ...
# 9974        3841     2472  \n\n\n     DATE: [**3031-4-6**] 1:56 PM\n     ...
# 9975        3841     2472                                             \n\n\n
# 9976        3841     2472                                             \n\n\n
# 9977        3841     2472  \n\n\n     DATE: [**3031-4-7**] 7:34 AM\n     ...
# 9978        3841     2472  \n\n\n     DATE: [**3031-4-7**] 7:34 AM\n     ...
# 9979        3841     2472  \n\n\n     DATE: [**3031-4-7**] 12:52 PM\n    ...
# 9980        3841     2472  \n\n\n     DATE: [**3031-4-7**] 7:33 AM\n     ...
# 9981        3841     2472  \n\n\n     DATE: [**3031-4-8**] 10:17 AM\n    ...
# 9982        3868    25308  \n\n\n     DATE: [**3430-4-22**] 2:48 PM\n    ...
# 9983        3868    25308  \n\n\n     DATE: [**3430-5-5**] 5:58 PM\n     ...
# 9984        3868    25308  \n\n\n     DATE: [**3430-5-7**] 9:56 AM\n     ...
# 9985        3868    27477  \n\n\n     DATE: [**3430-5-28**] 7:53 PM\n    ...
# 9986        3868    27477  \n\n\n     DATE: [**3430-5-29**] 10:05 AM\n   ...
# 9987        3868    27477  \n\n\n     DATE: [**3430-5-29**] 11:43 AM\n   ...
# 9988        3868    27477  \n\n\n     DATE: [**3430-5-29**] 11:43 AM\n   ...
# 9989        3868    27477  \n\n\n     DATE: [**3430-5-31**] 9:27 AM\n    ...
# 9990        3868    27477  \n\n\n     DATE: [**3430-5-31**] 9:27 AM\n    ...
# 9991        3868    27477  \n\n\n     DATE: [**3430-6-9**] 7:36 AM\n     ...
# 9992        3868      NaN  \n\n\n     DATE: [**3430-6-24**] 9:19 AM\n    ...
# 9993        3868      NaN  \n\n\n     DATE: [**3430-6-27**] 7:12 PM\n    ...
# 9994        3868      NaN  \n\n\n     DATE: [**3430-6-27**] 10:02 PM\n   ...
# 9995        3868      NaN  \n\n\n     DATE: [**3430-6-27**] 1:31 PM\n    ...
# 9996        3868      NaN  \n\n\n     DATE: [**3430-7-5**] 1:44 PM\n     ...
# 9997        3868      NaN  \n\n\n     DATE: [**3430-7-5**] 10:34 PM\n    ...
# 9998        3868      NaN  \n\n\n     DATE: [**3430-7-5**] 8:23 PM\n     ...
# 9999        3868      NaN  \n\n\n     DATE: [**3430-7-5**] 8:23 PM\n     ...
#
#                                              IMPRESSION
# 0                                                    \n
# 1                                                    \n
# 2     IMPRESSION:  Stable appearance of right pariet...
# 3     IMPRESSION:\n     \n     Cardiomegaly and mild...
# 4     IMPRESSION:\n     \n     Marked improvement in...
# 5     IMPRESSION: Stable cardiomegaly with pulmonary...
# 6     IMPRESSION:\n     1)  Confluent lingular opaci...
# 7     IMPRESSION:  No intracranial hemorrhage or mas...
# 8     IMPRESSION:\n     \n     1) No evidence of ret...
# 9     IMPRESSION:\n     \n     1) No evidence of ret...
# 10    IMPRESSION:\n     1. Persistence of interval s...
# 11                                                   \n
# 12    IMPRESSION:  Lingular infiltrate, probably not...
# 13    IMPRESSION:  1) Moderate, fixed left ventricul...
# 14    IMPRESSION:  No acute intracranial pathology s...
# 15                                                   \n
# 16    IMPRESSION: Probably mild cardiac enlargement ...
# 17                                                   \n
# 18                                                   \n
# 19    IMPRESSION: No pneumonia. Unusual ovoid densit...
# 20    IMPRESSION:\n     1)  There is a somewhat well...
# 21    IMPRESSION:\n     \n     Nonspecific, nonobstr...
# 22    IMPRESSION: No acute change from previous exam...
# 23    IMPRESSION:  No evidence of infiltrate or othe...
# 24    IMPRESSION:\n     \n     1.  No abnormal fluid...
# 25    IMPRESSION:\n     \n     1.  No abnormal fluid...
# 26    IMPRESSION:\n     \n     1.  No abnormal fluid...
# 27    IMPRESSION:\n     \n     1.  No abnormal fluid...
# 28    IMPRESSION:  Focal opacity adjacent to externa...
# 29    IMPRESSION:  MR of abdomen within normal limit...
# ...                                                 ...
# 9970  IMPRESSION:\n     1) Advancement of feeding tu...
# 9971                                                 \n
# 9972  IMPRESSION:\n     1.  Persistent bibasilar ate...
# 9973  IMPRESSION:\n     Markedly limited study due t...
# 9974  IMPRESSION:\n     Markedly limited study due t...
# 9975                                                 \n
# 9976                                                 \n
# 9977  IMPRESSION:\n     \n     Successful placement ...
# 9978  IMPRESSION:\n     \n     Successful placement ...
# 9979  IMPRESSION:  The NG tube is seen extending int...
# 9980  IMPRESSION:  Full patency of the inferior vena...
# 9981  IMPRESSION: CHF with bilateral pleural effusio...
# 9982  IMPRESSION:  Successful exchange of 4 French P...
# 9983  IMPRESSION:  Stable moderate interstitial edem...
# 9984  IMPRESSION:\n     1.  Successful exchange of s...
# 9985  IMPRESSION: 1) Persistent mild CHF.\n         ...
# 9986  IMPRESSION:  AP chest compared to [**5-29**], ...
# 9987  IMPRESSION:  Two fluoroscopic spot films are s...
# 9988  IMPRESSION:  Two fluoroscopic spot films are s...
# 9989  IMPRESSION:  Uncomplicated ultrasound and fluo...
# 9990  IMPRESSION:  Uncomplicated ultrasound and fluo...
# 9991  IMPRESSION:\n     \n     1) Central venous occ...
# 9992  IMPRESSION:\n     1.  Patent thoracic aortic s...
# 9993                                                 \n
# 9994  IMPRESSION:  AP chest compared to 2:35 p.m. to...
# 9995  IMPRESSION:\n     \n     1.  Interval decrease...
# 9996  IMPRESSION:  No significant change since prior...
# 9997                                                 \n
# 9998                                                 \n
# 9999                                                 \n
#
# [10000 rows x 4 columns]

# %%
# %matplotlib inline

# %%
import pymysql
import pandas as pd
import getpass
from textblob import TextBlob

# %%
conn = pymysql.connect(host="mysql",
                       port=3306,user="jovyan",
                       passwd=getpass.getpass("Enter MySQL passwd for jovyan"),db='mimic2')
cursor = conn.cursor()
# Out:
# Enter MySQL passwd for jovyan········
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-82-dc1f6af58aaa> in <module>()
#       1 conn = pymysql.connect(host="mysql",
#       2                        port=3306,user="jovyan",
# ----> 3                        passwd=getpass.getpass("Enter MySQL passwd for jovyan"),db='mimic2')
#       4 cursor = conn.cursor()
#
# /opt/conda/lib/python3.5/site-packages/pymysql/__init__.py in Connect(*args, **kwargs)
#      88     """
#      89     from .connections import Connection
# ---> 90     return Connection(*args, **kwargs)
#      91
#      92 from pymysql import connections as _orig_conn
#
# /opt/conda/lib/python3.5/site-packages/pymysql/connections.py in __init__(self, host, user, password, database, port, unix_socket, charset, sql_mode, read_default_file, conv, use_unicode, client_flag, cursorclass, init_command, connect_timeout, ssl, read_default_group, compress, named_pipe, no_delay, autocommit, db, passwd, local_infile, max_allowed_packet, defer_connect, auth_plugin_map, read_timeout, write_timeout)
#     686             self._sock = None
#     687         else:
# --> 688             self.connect()
#     689
#     690     def _create_ssl_ctx(self, sslp):
#
# /opt/conda/lib/python3.5/site-packages/pymysql/connections.py in connect(self, sock)
#     904
#     905             self._get_server_information()
# --> 906             self._request_authentication()
#     907
#     908             if self.sql_mode is not None:
#
# /opt/conda/lib/python3.5/site-packages/pymysql/connections.py in _request_authentication(self)
#    1112
#    1113         self.write_packet(data)
# -> 1114         auth_packet = self._read_packet()
#    1115
#    1116         # if authentication method isn't accepted the first byte
#
# /opt/conda/lib/python3.5/site-packages/pymysql/connections.py in _read_packet(self, packet_type)
#     979
#     980         packet = packet_type(buff, self.encoding)
# --> 981         packet.check_error()
#     982         return packet
#     983
#
# /opt/conda/lib/python3.5/site-packages/pymysql/connections.py in check_error(self)
#     391             errno = self.read_uint16()
#     392             if DEBUG: print("errno =", errno)
# --> 393             err.raise_mysql_exception(self._data)
#     394
#     395     def dump(self):
#
# /opt/conda/lib/python3.5/site-packages/pymysql/err.py in raise_mysql_exception(data)
#     105         errval = data[3:].decode('utf-8', 'replace')
#     106     errorclass = error_map.get(errno, InternalError)
# --> 107     raise errorclass(errno, errval)
#
# OperationalError: (1045, "Access denied for user 'jovyan'@'172.20.0.64' (using password: YES)")

# %%
from collections import Counter
word_counter = Counter(TextBlob(all_text).words)

# %%
word_counter.most_common(50)

# %% [markdown]
# ### Use Pandas and SQL to create a dataframe with the following:
# * subject_id
# * hospital admission id
# * text of the radiology report
# * Limit the number of reports to 10000

# %%
rad_data = \
pd.read_sql("""SELECT noteevents.subject_id, 
                      noteevents.hadm_id,
                      noteevents.text 
               FROM noteevents
               WHERE noteevents.category = 'RADIOLOGY_REPORT' LIMIT 10000""",conn)
rad_data.head(5)
# Out:
#    subject_id  hadm_id                                               text
# 0          56    28766  \n\n\n     DATE: [**2644-1-17**] 10:53 AM\n   ...
# 1          56    28766  \n\n\n     DATE: [**2644-1-17**] 10:53 AM\n   ...
# 2          56    28766  \n\n\n     DATE: [**2644-1-17**] 10:43 AM\n   ...
# 3          56    28766  \n\n\n     DATE: [**2644-1-17**] 6:37 AM\n    ...
# 4          56    28766  \n\n\n     DATE: [**2644-1-19**] 12:09 PM\n   ...

# %%
rad_data.shape
# Out:
# (10000, 3)

# %%
print(rad_data["text"][0])
# Out:
#      DATE: [**2644-1-17**] 10:53 AM
#      MR HEAD W & W/O CONTRAST; MR CONTRAST GADOLIN                   Clip # [**Clip Number (Radiology) 12569**]
#      Reason: R ICB and HX brain mets - eval - also with DWI for CVA Do MR
#       Contrast: MAGNEVIST Amt: 15
#      ______________________________________________________________________________
#      UNDERLYING MEDICAL CONDITION:
#       [**Age over 90 **] year old woman with lung CA- mets to brain
#      REASON FOR THIS EXAMINATION:
#       R ICB and HX brain mets - eval - also with DWI for CVA Do MRI both with and
#       without contast please
#      ______________________________________________________________________________
#                                      FINAL REPORT
#      EXAMINATION:  MRI of the brain with and without gadolinium.
#
#      INDICATION:  [**Age over 90 **] year old woman with lung cancer and right intracranial bleed
#      and history of brain metastases.  Please evaluate for acute infarct.
#
#      TECHNIQUE:  Multiplanar T1 and T2-weighted images of the brain with gadolinium
#      according to standard departmental protocol.  No prior study for comparison.
#
#      FINDINGS:  On diffusion-weighted images there is a small area of restricted
#      diffusion along the falx within the left occipitotemporal lobe.  It is also
#      bright on FLAIR-weighted images and may represent a subacute infarct. Clinical
#      correlation is recommended.  On gradient echo images there is a large area of
#      intraparenchymal hemorrhage within the right parietal lobe and left thalamus
#      which following administration of gadolinium reveals ring-enhancing lesions.
#      These are suspicious for hemorrhagic metastases given the patient's history.
#      Additional ring-enhancing lesions throughout the supra- and infratentorial
#      compartments are visualized.  There is a moderate amount of peritumoral edema
#      involving the right parietal lobe lesion in addition to a second right
#      parietal lesion along the falx high in the vertex.  The other areas of
#      metastases reveal a minimal amount of peritumoral edema.

# %% [markdown]
# ## Section Splitting
#
# <img src="http://medicine.utah.edu/dbmi/images/faculty/Chapman,Wendy_240x360.jpg"
# alt="Wendy Chapman" width="128">
#
# Clinical reports are often divided into sections. Physicians are taught to write their reports in the SOAP format: subjective information, objective information, assessment, and plan, and sections often reflect this process. Information each setion may be formatted differently. For example, subjective information is often narrative, telling a story of the patient's description of their past medical history and their current issues. The objective section may be much more telegraphic with shortened descriptions of measurements like blood pressure and heart rate, such as "120/80 88". You may need different NLP techniques to accurately extract information out of different sections. Sentence splitting, for example, may be different in subjective versus objective sections. Radiology reports are not in the SOAP format, but section identification can still be very important, because in these reports the radiologist describes what she sees on the radiographic image then sometimes summarizes her impression of what the observations may represent, such as "the infiltrate could be consistent with pneumonia." For some tasks, you may only be interested in the impression, which has more weight than the reasoning that occurs in the Findings section.

# %% [markdown]
# ## Exercise
#
# Write a function that returns the impression section of a report. The function will take two arguments:
#
# 1. The text to search for the impression section is the first positional argument.
# 1. A list of phrases to use to identify the impression section.
#
# Not every report will have a section labeled "IMPRESSION". You can consider "INTERPRETATION" and "CONCLUSIONS" as synonyms for "IMPRESSION"
#
# If you cannot identify the impresison section (or equivalent), return an empty string.
#
# #### Hints
#
# * Use a for loop  to iterate across
# * Use the find method of a string to identify where in the string the impression section occurs
# * Use slicing to grab the impression section

# %%
def find_impression(report, section=None):
    if section==None:
        section=["IMPRESSION:", "INTERPRETATION:", "CONCLUSIONS:"]
    for s in section:
        index=report.find(s)
        if s !=-1:
            return report[index:]
    return ""
print (find_impression(rad_data["text"][1000]))
# Out:
# IMPRESSION:  The tip of the Swan-Ganz catheter overlies the main pulmonary
#      arterial trunk.  Otherwise, no significant change.

# %%
def find_impression(report, section=None):
    if section==None:
        section=["IMPRESSION:", "INTERPRETATION:", "CONCLUSIONS:"]
    for s in section:
        index=report.find(s)
        if s !=-1:
            return report[index:].split(s)[1]
    return ""
print (find_impression(rad_data["text"][100]))
print ("*"*42)
print(rad_data["text"][100])
# Out:
#  1) Stable appearance of small pleural effusion and retrocardiac
#      opacity. 2) Kink in right sided subclavian central venous line in the region
#      where it likely enters the skin.
#
#
# ******************************************
#
#
#
#      DATE: [**2682-9-8**] 6:10 AM
#      CHEST (PORTABLE AP)                                             Clip # [**Clip Number (Radiology) 12445**]
#      Reason: please eval for line placement
#      ______________________________________________________________________________
#      UNDERLYING MEDICAL CONDITION:
#           76 year old man with hypotension, vfib arrest, status post RIJ line
#       placement and Swan.
#      REASON FOR THIS EXAMINATION:
#       please eval for line placement
#      ______________________________________________________________________________
#                                      FINAL REPORT
#      06:34.
#
#      INDICATION: Post line placement.
#
#      Comparison is made to study of 5 hours previously.
#
#      FINDINGS: ETT, PA catheter, right subclavian line, and left sided PICC are
#      unchanged in position. A kink is seen in the right subclavian line where it
#      likely enters the skin.
#
#      Heart, pulmonary vessels, and pulmonary parenchyma are unchanged.
#
#      IMPRESSION: 1) Stable appearance of small pleural effusion and retrocardiac
#      opacity. 2) Kink in right sided subclavian central venous line in the region
#      where it likely enters the skin.

# %% [markdown]
# ## Exercise
#
# Use ``apply()`` to create a new column in the ``rad_data`` named "IMPRESSIONS" with the string identified with ``find_impression()``.

# %%
rad_data.head()
# Out:
#    subject_id  hadm_id                                               text
# 0          56    28766  \n\n\n     DATE: [**2644-1-17**] 10:53 AM\n   ...
# 1          56    28766  \n\n\n     DATE: [**2644-1-17**] 10:53 AM\n   ...
# 2          56    28766  \n\n\n     DATE: [**2644-1-17**] 10:43 AM\n   ...
# 3          56    28766  \n\n\n     DATE: [**2644-1-17**] 6:37 AM\n    ...
# 4          56    28766  \n\n\n     DATE: [**2644-1-19**] 12:09 PM\n   ...

# %%
print (rad_data["text"][1])
# Out:
#      DATE: [**2644-1-17**] 10:53 AM
#      MR HEAD W & W/O CONTRAST; MR CONTRAST GADOLIN                   Clip # [**Clip Number (Radiology) 12569**]
#      Reason: R ICB and HX brain mets - eval - also with DWI for CVA Do MR
#       Contrast: MAGNEVIST Amt: 15
#      ______________________________________________________________________________
#      UNDERLYING MEDICAL CONDITION:
#       [**Age over 90 **] year old woman with lung CA- mets to brain
#      REASON FOR THIS EXAMINATION:
#       R ICB and HX brain mets - eval - also with DWI for CVA Do MRI both with and
#       without contast please
#      ______________________________________________________________________________
#                                      FINAL REPORT
#      EXAMINATION:  MRI of the brain with and without gadolinium.
#
#      INDICATION:  [**Age over 90 **] year old woman with lung cancer and right intracranial bleed
#      and history of brain metastases.  Please evaluate for acute infarct.
#
#      TECHNIQUE:  Multiplanar T1 and T2-weighted images of the brain with gadolinium
#      according to standard departmental protocol.  No prior study for comparison.
#
#      FINDINGS:  On diffusion-weighted images there is a small area of restricted
#      diffusion along the falx within the left occipitotemporal lobe.  It is also
#      bright on FLAIR-weighted images and may represent a subacute infarct. Clinical
#      correlation is recommended.  On gradient echo images there is a large area of
#      intraparenchymal hemorrhage within the right parietal lobe and left thalamus
#      which following administration of gadolinium reveals ring-enhancing lesions.
#      These are suspicious for hemorrhagic metastases given the patient's history.
#      Additional ring-enhancing lesions throughout the supra- and infratentorial
#      compartments are visualized.  There is a moderate amount of peritumoral edema
#      involving the right parietal lobe lesion in addition to a second right
#      parietal lesion along the falx high in the vertex.  The other areas of
#      metastases reveal a minimal amount of peritumoral edema.

# %% [markdown]
# ## How else might we need to break up a report?
#
# * How would I break a report into sentences?
# * How would I break a report into words?

# %% [markdown]
# ## Group Exercise
#
# ### Create a single string with all the reports
#
# #### Hints, etc.
# * Use List Comprehension
# * Use string joins
# * Iterate over the rows of the data frame
# * Use TextBlob to get words

# %%
for _, row in rad_data[:10].iterrows():
    print(row)
# Out:
# subject_id                                                   56
# hadm_id                                                   28766
# text          \n\n\n     DATE: [**2644-1-17**] 10:53 AM\n   ...
# Name: 0, dtype: object
# subject_id                                                   56
# hadm_id                                                   28766
# text          \n\n\n     DATE: [**2644-1-17**] 10:53 AM\n   ...
# Name: 1, dtype: object
# subject_id                                                   56
# hadm_id                                                   28766
# text          \n\n\n     DATE: [**2644-1-17**] 10:43 AM\n   ...
# Name: 2, dtype: object
# subject_id                                                   56
# hadm_id                                                   28766
# text          \n\n\n     DATE: [**2644-1-17**] 6:37 AM\n    ...
# Name: 3, dtype: object
# subject_id                                                   56
# hadm_id                                                   28766
# text          \n\n\n     DATE: [**2644-1-19**] 12:09 PM\n   ...
# Name: 4, dtype: object
# subject_id                                                   37
# hadm_id                                                   18052
# text          \n\n\n     DATE: [**3264-8-14**] 6:06 AM\n    ...
# Name: 5, dtype: object
# subject_id                                                   37
# hadm_id                                                   18052
# text          \n\n\n     DATE: [**3264-8-14**] 10:57 AM\n   ...
# Name: 6, dtype: object
# subject_id                                                   37
# hadm_id                                                   18052
# text          \n\n\n     DATE: [**3264-8-15**] 9:26 AM\n    ...
# Name: 7, dtype: object
# subject_id                                                   37
# hadm_id                                                   18052
# text          \n\n\n     DATE: [**3264-8-15**] 3:49 PM\n    ...
# Name: 8, dtype: object
# subject_id                                                   37
# hadm_id                                                   18052
# text          \n\n\n     DATE: [**3264-8-15**] 3:49 PM\n    ...
# Name: 9, dtype: object

# %%
rad_data.head()
rad_data["IMPRESSION"]=rad_data.apply(lambda row: find_impression(row["text"]), axis=1)
rad_data.head()
# Out:
#    subject_id  hadm_id                                               text  \
# 0          56    28766  \n\n\n     DATE: [**2644-1-17**] 10:53 AM\n   ...
# 1          56    28766  \n\n\n     DATE: [**2644-1-17**] 10:53 AM\n   ...
# 2          56    28766  \n\n\n     DATE: [**2644-1-17**] 10:43 AM\n   ...
# 3          56    28766  \n\n\n     DATE: [**2644-1-17**] 6:37 AM\n    ...
# 4          56    28766  \n\n\n     DATE: [**2644-1-19**] 12:09 PM\n   ...
#
#                                           IMPRESSION
# 0                                                 \n
# 1                                                 \n
# 2  IMPRESSION:  Stable appearance of right pariet...
# 3  IMPRESSION:\n     \n     Cardiomegaly and mild...
# 4  IMPRESSION:\n     \n     Marked improvement in...

# %%
imps=[row["IMPRESSION"] for _, row in rad_data[:5].iterrows()]

# %%
imps=[] 
for _, row in rad_data[:5].iterrows():
    imps.append(row["IMPRESSION"])

# %%
imps[2]
# Out:
# 'IMPRESSION:  Stable appearance of right parietal lobe and left thalamic\n     hemorrhages, which are concerning for hemorrhagic metastasis in this patient\n     with known metastatic lung carcinoma to the brain.\n     \n     \n\n'

# %%
all_text= ""
for impression in imps:
        all_text=all_text + " " +impression

# %%
len(all_text)
# Out:
# 1373

# %%
all_text=" ".join(imps)

# %%
all_text ="  ".join([row["IMPRESSION"] for _, row in rad_data.iterrows()])

# %%
len(all_text)
# Out:
# 3138139

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud
plt.imshow(WordCloud(min_font_size=6, scale=20, height=600, width=600). generate(all_text))
plt.axis("off")
# Out:
# (-0.5, 11999.5, 11999.5, -0.5)
